# %%
import os
import geopandas as gpd

# %%
pth = os.path.join('..', 'data', 'geodataframe_density.gpkg')
gdf = gpd.read_file(pth); gdf
# Out:
#                city         state        country  latitude  longitude  \
# 0           uruapan     michoacan         mexico  19.41116 -102.05644
# 1             tepic       nayarit         mexico  21.50951 -104.89569
# 2            fuzhou        fujian          china  26.06139  119.30611
# 3            kunsan       jeonbuk    south korea  35.97860  126.71140
# 4            gunsan  jeollabuk do    south korea  35.97861  126.71139
# ...             ...           ...            ...       ...        ...
# 24022      kotzebue        alaska  united states  66.89846 -162.59809
# 24023    wainwright        alaska  united states  70.63694 -160.03833
# 24024       solomon        alaska  united states  64.55961 -164.44310
# 24025          nome        alaska  united states  64.50111 -165.40639
# 24026  dutch harbor        alaska  united states  53.88980 -166.54220
#
#        population               msa     US                     cluster  \
# ...

# %%
gdf.drop(columns = ['US', 'cluster_ref', 'log10_dpc', 'geometry'], inplace = True)

# %%
gdf.to_csv(os.path.join('..', 'data', 'ClusteringResults.csv'))
